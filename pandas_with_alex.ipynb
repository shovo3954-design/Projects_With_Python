# %%
import pandas as pd

# %%
pd.read_table(r"D:\All_File\countries of the world.txt")

# %%
df = pd.read_table(r"D:\All_File\countries of the world.txt", sep = "\t")

# %%
print(df)

# %%
df = pd.read_json(r"D:\All_File\json_sample.json")
df

# %%
df = pd.read_excel(r"D:\All_File\world_population_excel_workbook.xlsx")
df.head()

# %%
df2 = pd.read_excel(r"D:\All_File\world_population_excel_workbook.xlsx",sheet_name = 'Sheet1')
df2

# %%
pd.set_option("display.max.rows", 235)

# %%
pd.set_option("display.max.columns", 40)

# %%
df.info()

# %%
df2.shape

# %%
df2["Rank"]

# %%
df2.loc[19]

# %%
df2.loc[74]

# %%
import sys
print(sys.executable)
