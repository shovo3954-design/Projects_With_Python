# %%
## Fitering and Ordering

import pandas as pd

# %%
df = pd.read_csv(r"D:\All_File\world_population.csv")
df

# %%
df[df["Rank"] <= 10]

# %%
specific_countries = ["Bangladesh", "Brazil"]

df[df["Country"].isin(specific_countries)]

# %%
df[df["Country"].str.contains('Russia')]

# %%
df2 = df.set_index("Country")
df2

# %%
items = ["Continent", "CCA3"]

df2.filter(items)

# %%
united = "United"

df2.filter(like = "United", axis = 0)

# %%
df2.loc["United States"]

# %%
df2.iloc[2]

# %%
df2[df2["Rank"] <=10].sort_values(by= "Rank", ascending = True)
