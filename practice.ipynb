# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\UTBD\Downloads\orders.csv")

# %%
pd.set_option('display.expand_frame_repr', False)

# %%
print(df)

# %%
df.head()

# %%
df.tail()

# %%
df.head(12)

# %%
df.tail(21)

# %%
type(df)

# %%
set(df)

# %%
df.iloc[1]

# %%
df.iloc[35]["Country"]

# %%
df.iloc[4]["Product"]

# %%
df.info()

# %%
len(df)

# %%
df.columns

# %%
df.index

# %%
df.describe()

# %%
df["Country"]

# %%
data = pd.read_csv(r"C:\Users\UTBD\Downloads\orders.csv", header = None)
print(data)

# %%
data.info()

# %%
data.index
