# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\UTBD\Downloads\orders.csv")

# %%
import pandas as pd
pd.set_option('display.expand_frame_repr', False)

# %%
print(df.head())

# %%
print(df)

# %%
print(df.tail())

# %%
print(df.tail(13))

# %%
print(df.info())

# %%
print(df.describe())

# %%
df.columns

# %%
df.index

# %%
df["Country"]

# %%
len(df["Country"])

# %%
set(df["Country"]) ## Unique value

# %%
df[["Country", "Product"]]

# %%
df.iloc[0]

# %%
df.iloc[1]

# %%
list(df.iloc[2])

# %%
df.iloc[2]["Country"]

# %%
 df[df["Country"] == "UAE"]   # Filtering

# %%
df[df["Quantity"] == 5]## Filtering

# %%
df[(df["Product"] == "Office Chair") & (df["Category"] == "Furniture")] ## More filtering

# %%
print(df)

# %%
df[(df["Product"] == "Office Chair") | (df["Category"] == "Furniture")] ## Or

# %%
df[df["Quantity"] > 2]

# %%
df[df["Quantity"] < 5]

# %%
df[df["Quantity"] == 5]

# %%
df[df["CustomerName"].str.startswith("A")]

# %%
df[df["CustomerName"].str.endswith("a")]

# %%
df[df["CustomerName"].str.endswith("e")]

# %%
df[df["CustomerName"].str.endswith("n")]

# %%
df[df["Country"].isin(['USA', 'Sweden', 'UK'])]

# %%
df[~df["Country"].isin(["USA", "UK", "Sweden"])]

# %%
df.loc[df["CustomerName"] == "Anna Ivanova", "Product"]= "Book"

# %%
df.loc[df["CustomerName"] == "Anna Ivanova"]
# Out:
#     OrderID  CustomerName Product   Category  Quantity  Price   OrderDate Shipped  Country
# 39     1040  Anna Ivanova    Book  Furniture         1   35.0  2024-07-11     Yes  Ukraine

# %%
df.loc[df["CustomerName"] == "Anna Ivanova", "Country"] = "Bangladesh"

# %%
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity   Price   OrderDate Shipped       Country
# 0      1001        John Smith                 Laptop  Electronics         1  1200.0  2024-06-01     Yes           USA
# 1      1002         Sarah Lee             Headphones  Electronics         2   150.0  2024-06-03      No        Canada
# 2      1003          Ali Khan           Office Chair    Furniture         1   300.0  2024-06-04     Yes           UAE
# 3      1004        Alice Wong              Desk Lamp    Furniture         3    45.0  2024-06-05     Yes     Singapore
# 4      1005     Carlos Mendez               Keyboard  Electronics         2    80.0  2024-06-06      No        Mexico
# 5      1006      Nora Ibrahim               Notebook   Stationery         5     5.0  2024-06-07     Yes           UAE
# 6      1007       Emily Davis          Standing Desk    Furniture         1   450.0  2024-06-08     Yes            UK
# ...

# %%
df["CustomerName"] = df["CustomerName"].str.upper()

# %%
df["CustomerName"]
# Out:
# 0           JOHN SMITH
# 1            SARAH LEE
# 2             ALI KHAN
# 3           ALICE WONG
# 4        CARLOS MENDEZ
# 5         NORA IBRAHIM
# 6          EMILY DAVIS
# 7           JAMES PARK
# 8          MARIA ROSSI
# 9     TAKESHI NAKAMURA
# 10       SOPHIE MARTIN
# 11           RAJ PATEL
# 12         EMMA WILSON
# 13     DIEGO RODRIGUEZ
# 14           LISA CHEN
# 15        AHMED HASSAN
# 16       ANNA KOWALSKI
# 17       MICHAEL BROWN
# 18         YUKI TANAKA
# 19     FATIMA AL-ZAHRA
# 20      DAVID THOMPSON
# 21      ISABELLA SILVA
# 22      OLIVER SCHMIDT
# 23          ZARA AHMED
# 24      LUCAS ANDERSON
# 25        CHLOE DUBOIS
# 26       MIGUEL TORRES
# 27         NINA PETROV
# 28        SEO-YEON KIM
# 29     GIUSEPPE ROMANO
# 30        AMIRA HASSAN
# 31       THOMAS MÜLLER
# 32     SOFIA RODRIGUEZ
# 33        ALEX JOHNSON
# 34       YUKI YAMAMOTO
# 35       EMMA THOMPSON
# 36       CARLOS SANTOS
# 37      LEILA MANSOURI
# 38          DANIEL KIM
# 39        ANNA IVANOVA
# ...

# %%
df["Product"] = df["Product"].str.lower()

# %%
df["Product"]
# Out:
# 0                    laptop
# 1                headphones
# 2              office chair
# 3                 desk lamp
# 4                  keyboard
# 5                  notebook
# 6             standing desk
# 7                   monitor
# 8                       pen
# 9                     mouse
# 10                   webcam
# 11             file cabinet
# 12                  stapler
# 13                usb drive
# 14                bookshelf
# 15            printer paper
# 16           wireless mouse
# 17           desk organizer
# 18               calculator
# 19               whiteboard
# 20             highlighters
# 21        bluetooth speaker
# 22             office plant
# 23             sticky notes
# 24             tablet stand
# 25           paper shredder
# 26           desk chair mat
# 27             binder clips
# 28        wireless keyboard
# 29            desk calendar
# 30                  usb hub
# 31         document scanner
# 32    desk drawer organizer
# ...

# %%
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity   Price   OrderDate Shipped       Country
# 0      1001        JOHN SMITH                 laptop  Electronics         1  1200.0  2024-06-01     Yes           USA
# 1      1002         SARAH LEE             headphones  Electronics         2   150.0  2024-06-03      No        Canada
# 2      1003          ALI KHAN           office chair    Furniture         1   300.0  2024-06-04     Yes           UAE
# 3      1004        ALICE WONG              desk lamp    Furniture         3    45.0  2024-06-05     Yes     Singapore
# 4      1005     CARLOS MENDEZ               keyboard  Electronics         2    80.0  2024-06-06      No        Mexico
# 5      1006      NORA IBRAHIM               notebook   Stationery         5     5.0  2024-06-07     Yes           UAE
# 6      1007       EMILY DAVIS          standing desk    Furniture         1   450.0  2024-06-08     Yes            UK
# ...

# %%
df["Product"] = df["Product"].str.title()

# %%
df["Product"]
# Out:
# 0                    Laptop
# 1                Headphones
# 2              Office Chair
# 3                 Desk Lamp
# 4                  Keyboard
# 5                  Notebook
# 6             Standing Desk
# 7                   Monitor
# 8                       Pen
# 9                     Mouse
# 10                   Webcam
# 11             File Cabinet
# 12                  Stapler
# 13                Usb Drive
# 14                Bookshelf
# 15            Printer Paper
# 16           Wireless Mouse
# 17           Desk Organizer
# 18               Calculator
# 19               Whiteboard
# 20             Highlighters
# 21        Bluetooth Speaker
# 22             Office Plant
# 23             Sticky Notes
# 24             Tablet Stand
# 25           Paper Shredder
# 26           Desk Chair Mat
# 27             Binder Clips
# 28        Wireless Keyboard
# 29            Desk Calendar
# 30                  Usb Hub
# 31         Document Scanner
# 32    Desk Drawer Organizer
# ...

# %%
df = df.drop(5) ## To remove something

# %%
df.head()
# Out:
#    OrderID   CustomerName        Product     Category  Quantity  Price   OrderDate Shipped    Country
# 1     1002      SARAH LEE     Headphones  Electronics         2  150.0  2024-06-03      No     Canada
# 2     1003       ALI KHAN   Office Chair    Furniture         1  300.0  2024-06-04     Yes        UAE
# 3     1004     ALICE WONG      Desk Lamp    Furniture         3   45.0  2024-06-05     Yes  Singapore
# 4     1005  CARLOS MENDEZ       Keyboard  Electronics         2   80.0  2024-06-06      No     Mexico
# 6     1007    EMILY DAVIS  Standing Desk    Furniture         1  450.0  2024-06-08     Yes         UK

# %%
df = df.dropna()  ## To remove emty data

# %%
df.rename(columns= {"OrderID": "Order Id"}, inplace = True)

# %%
df.rename(columns = {"CustomerName": "Customer Name"}, inplace = True)

# %%
df.head(3)
# Out:
#    Order Id Customer Name       Product     Category  Quantity  Price   OrderDate Shipped    Country
# 1      1002     SARAH LEE    Headphones  Electronics         2  150.0  2024-06-03      No     Canada
# 2      1003      ALI KHAN  Office Chair    Furniture         1  300.0  2024-06-04     Yes        UAE
# 3      1004    ALICE WONG     Desk Lamp    Furniture         3   45.0  2024-06-05     Yes  Singapore

# %%
df.rename(columns = {"OrderDate": "Order Date"}, inplace = True)

# %%
df.tail(3)
# Out:
#     Order Id   Customer Name      Product     Category  Quantity  Price  Order Date Shipped      Country
# 37      1038  LEILA MANSOURI     Desk Pad    Furniture         1   28.0  2024-07-09     Yes         Iran
# 38      1039      DANIEL KIM  Power Strip  Electronics         2   18.0  2024-07-10      No  South Korea
# 39      1040    ANNA IVANOVA         Book    Furniture         1   35.0  2024-07-11     Yes   Bangladesh

# %%
df["Country"].value_counts()
# Out:
# Country
# Japan           3
# South Korea     3
# Canada          2
# UK              2
# France          2
# Italy           2
# Germany         2
# USA             2
# Mexico          1
# India           1
# UAE             1
# Singapore       1
# Spain           1
# Australia       1
# Egypt           1
# China           1
# Poland          1
# Saudi Arabia    1
# Brazil          1
# Pakistan        1
# Sweden          1
# Argentina       1
# Russia          1
# Morocco         1
# Colombia        1
# Portugal        1
# Iran            1
# Bangladesh      1
# Name: count, dtype: int64

# %%
df["Product"].value_counts()
# Out:
# Product
# Headphones               1
# Office Chair             1
# Desk Lamp                1
# Keyboard                 1
# Standing Desk            1
# Monitor                  1
# Pen                      1
# Mouse                    1
# Webcam                   1
# File Cabinet             1
# Stapler                  1
# Usb Drive                1
# Bookshelf                1
# Printer Paper            1
# Wireless Mouse           1
# Desk Organizer           1
# Calculator               1
# Whiteboard               1
# Highlighters             1
# Bluetooth Speaker        1
# Office Plant             1
# Sticky Notes             1
# Tablet Stand             1
# Paper Shredder           1
# Desk Chair Mat           1
# Binder Clips             1
# Wireless Keyboard        1
# Desk Calendar            1
# Usb Hub                  1
# Document Scanner         1
# Desk Drawer Organizer    1
# Index Cards              1
# Monitor Stand            1
# Desk Lamp With Usb       1
# ...

# %%
df.groupby("Country")["Price"].sum()
# Out:
# Country
# Argentina        22.0
# Australia        12.0
# Bangladesh       35.0
# Brazil           95.0
# Canada          153.5
# China           280.0
# Colombia         42.0
# Egypt             8.0
# France          160.0
# Germany         175.0
# India           180.0
# Iran             28.0
# Italy            19.5
# Japan           105.0
# Mexico           80.0
# Morocco          32.0
# Pakistan          4.0
# Poland           45.0
# Portugal        125.0
# Russia            2.5
# Saudi Arabia    120.0
# Singapore        45.0
# South Korea     348.0
# Spain            25.0
# Sweden           28.0
# UAE             300.0
# UK              518.0
# USA              65.8
# Name: Price, dtype: float64

# %%
df.sort_values("Price", ascending = False)
# Out:
#     Order Id     Customer Name                Product     Category  Quantity  Price  Order Date Shipped       Country
# 6       1007       EMILY DAVIS          Standing Desk    Furniture         1  450.0  2024-06-08     Yes            UK
# 2       1003          ALI KHAN           Office Chair    Furniture         1  300.0  2024-06-04     Yes           UAE
# 14      1015         LISA CHEN              Bookshelf    Furniture         1  280.0  2024-06-16      No         China
# 7       1008        JAMES PARK                Monitor  Electronics         2  220.0  2024-06-09      No   South Korea
# 11      1012         RAJ PATEL           File Cabinet    Furniture         2  180.0  2024-06-13      No         India
# 1       1002         SARAH LEE             Headphones  Electronics         2  150.0  2024-06-03      No        Canada
# 31      1032     THOMAS MÜLLER       Document Scanner  Electronics         1  140.0  2024-07-03     Yes       Germany
# ...

# %%
df.to_csv("New_File.csv", index = False)
